# %% [markdown]
# **Soal 1. Data Preparation**
#
# Bacalah Dataset dengan memberikan beberapa argumen sehingga bisa membaca datetime

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

#code here
climate = pd.read_csv('drive/My Drive/Bootcamp Data Science Python/Pekan 2/5. Time Series/climate_change.csv', index_col='date', parse_dates=True)

climate
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1TqrXs9JStRXqiF0NIWiMdo5r8CQ-S74-)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# Soal 2. Selection
#
# Tampilkan data keseluruhan untuk tahun 2015 di bulan November

# %%
#code here
climate['2015-11']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#             meantemp  humidity  wind_speed  meanpressure
# date
# 2015-11-01    22.875    70.500      0.9250      1016.250
# 2015-11-02    23.375    71.375      0.4625      1015.875
# 2015-11-03    24.000    67.875      0.4750      1014.250
# 2015-11-04    23.750    69.000      0.9250      1012.250
# 2015-11-05    22.125    75.250      5.1000      1012.375
# 2015-11-06    22.875    74.375      2.3250      1012.750
# 2015-11-07    21.875    74.875      1.1625      1014.625
# 2015-11-08    21.875    70.250      1.8625      1015.875
# 2015-11-09    21.750    73.625      0.7000      1015.000
# 2015-11-10    22.750    72.625      0.7000      1013.500
# 2015-11-11    21.875    59.500      4.6375      1014.375
# ...

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1ABMLSmdQ817PIdxW1v7rUKelOj_W241g)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Soal 3. Filtering**
#
# Tampilkan data perubahan iklim pada 1 bulan terakhir di tahun 2016 dan jawablah pertanyaan berikut:
#
# Berapakah rata-rata temperatur tertinggi?

# %%
# 3.1 data perubahan iklim pada 1 bulan terakhir di tahun 2016
#code here
climate['2016'].last('1M')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-12-01  19.750000  84.000000    2.704167   1016.875000
# 2016-12-02  19.208333  75.875000    4.945833   1017.750000
# 2016-12-03  21.208333  52.166667    5.866667   1019.333333
# 2016-12-04  18.900000  55.250000    5.666667   1019.700000
# 2016-12-05  18.636364  56.590909    4.952381   1017.045455
# 2016-12-06  18.538462  69.923077    2.503846   1017.961538
# 2016-12-07  18.250000  74.350000    0.925000   1017.421053
# 2016-12-08  16.900000  73.300000    1.765000   1016.200000
# 2016-12-09  19.416667  68.125000    1.312500   1013.416667
# 2016-12-10  16.444444  82.833333    5.355556   1014.000000
# ...

# %%
# rata-rata temperatur tertinggi
print('Rata-rata temperatur tertinggi pada 1 bulan terakhir tahun 2016: \n')
climate['2016'].last('1M').agg({'meantemp':'max'})
# Out:
# Rata-rata temperatur tertinggi pada 1 bulan terakhir tahun 2016:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# meantemp    21.208333
# dtype: float64

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1X2hXsvrRGvqHqtc5BFbVvRXwh5YxBQ_P)

# %% [markdown]
# Jawab disini:
# ***Rata-rata suhu tertinggi pada 1 bulan terakhir tahun 2016 adalah: 21.208333***

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Soal 4. Time grouping**
#
#
#
# *   Lakukan grouping data perubahan iklim pada tahun 2016 berdasarkan frekuensi 1 bulan dengan memberikan agregasi max pada kolom meantemp. humidity, wind_speed dan meanpressure!
# *   Berikan analisa, di bulan apa rata-rata temperatur, humidity, wind_speed dan meanpressure tertinggi?

# %%
#code here
climate['2016'].groupby(pd.Grouper(freq='1M'))[['meantemp','humidity','wind_speed','meanpressure']].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-01-31  20.142857  88.833333   11.240000   1021.142857
# 2016-02-29  23.875000  77.000000   17.137500   1020.071429
# 2016-03-31  30.000000  67.800000   22.100000   7679.333333
# 2016-04-30  35.687500  44.250000   19.653846   1009.400000
# 2016-05-31  38.272727  74.812500   18.425000   1007.466667
# 2016-06-30  38.200000  75.071429   21.306250   1002.833333
# 2016-07-31  34.187500  93.875000   13.656250   1004.625000
# 2016-08-31  33.809524  89.555556   14.666667   1006.200000
# 2016-09-30  33.444444  87.240000   17.908333   1352.615385
# 2016-10-31  33.269231  71.875000   15.825000   1017.807692
# ...

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1s2Y8Dc3M3xbG-51mTuTmXUFgLvHDvc5Q)

# %%
# Buat dataframe baru untuk rata-rata climate per 1 bulan pada 2016

rata_rata = climate['2016'].groupby(pd.Grouper(freq='1M'))[['meantemp','humidity','wind_speed','meanpressure']].mean().copy()
rata_rata
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-01-31  15.139363  77.932892    4.285177   1017.021621
# 2016-02-29  19.025676  62.385095    5.950592   1016.055790
# 2016-03-31  25.701075  55.037324    7.204904   1227.166990
# 2016-04-30  32.550029  29.244164    9.687357   1005.738005
# 2016-05-31  34.728726  38.958726    9.506423   1001.847837
# 2016-06-30  34.946836  51.759739    9.052079    998.050478
# 2016-07-31  30.875806  75.429839    6.207018    997.788172
# 2016-08-31  31.116578  72.993345    7.168392    934.847045
# 2016-09-30  31.479768  61.011111    7.508029   1016.249791
# ...

# %%
# Rata-rata Meantemp tertinggi:
max_meantemp = rata_rata['meantemp'].max()

#print(max_meantemp)
rata_rata.loc[rata_rata['meantemp'] == max_meantemp]
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-06-30  34.946836  51.759739    9.052079    998.050478

# %%
# Rata-rata Humidity Tertinggi
max_humidity = rata_rata['humidity'].max()

rata_rata.loc[rata_rata['humidity'] == max_humidity]
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-01-31  15.139363  77.932892    4.285177   1017.021621

# %%
# Rata-rata Wind speed tertinggi

max_wind_speed = rata_rata['wind_speed'].max()

rata_rata.loc[rata_rata['wind_speed'] == max_wind_speed]
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-04-30  32.550029  29.244164    9.687357   1005.738005

# %%
# Rata-rata Meanpressure tertinggi

max_meanpressure = rata_rata['meanpressure'].max()

rata_rata.loc[rata_rata['meanpressure'] == max_meanpressure]
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-03-31  25.701075  55.037324    7.204904    1227.16699

# %% [markdown]
# Jawab disini:
#
#
# 1.   Meantemp tertinggi terjadi pada bulan: Juni ***2016-06-30***
# 2.   Humidity tertinggi terjadi pada bulan: Januari ***2016-01-31***
# 3.   Wind speed tertinggi terjadi pada bulan: April ***2016-04-30***
# 4.   Meanpressure tertinggi terjadi pada bulan: Maret ***2016-03-31***

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Soal 5. Time Differenced**
#
# Tunjukkanlah perubahan iklim di tahun 2016 pada minggu terakhir

# %%
#code here

climate['2016'].last('1W').diff()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#             meantemp   humidity  wind_speed  meanpressure
# date
# 2016-12-26       NaN        NaN         NaN           NaN
# 2016-12-27 -0.292857  -7.307143   -0.449211      0.247619
# 2016-12-28  0.367391   0.493478   -4.787174     -1.634783
# 2016-12-29 -1.979296  19.813665    2.452174      1.339545
# 2016-12-30 -1.142857   1.809524    0.266667      1.000000
# 2016-12-31  0.957393  -2.666667    1.058333     -1.804762

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1miJBQeGMyUS_G3bwP14Plo4s5950oYy5)

# %% [markdown]
# ---
#
#
#
# ---
